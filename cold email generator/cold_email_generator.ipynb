# %%
# !pip install langchain-groq

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0,
    groq_api_key='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',
    model_name="llama-3.3-70b-versatile"
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/accounting-admin-jackson/job/R-52178")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Accounting Admin - Jackson
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):
        """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
res.content
# Out:
# '```json\n{\n  "role": "Accounting Admin",\n  "experience": "1 year of retail or consumer service experience",\n  "skills": [\n    "Proficient knowledge of office practices, procedures, and equipment",\n    "Intermediate skills in Microsoft Office products including Word and Excel",\n    "Ability to learn and train on the latest products and technologies",\n    "Ability to communicate in English",\n    "Strong customer service skills and the ability to exercise a high degree of professionalism",\n    "Strong attention to detail and deadlines"\n  ],\n  "description": "Administer advanced cashiering tasks, support scheduling, review associate tech functionality, and perform standard cashiering duties. The ideal candidate will have a strong ability to work in a fast-paced environment, be flexible, and have excellent communication skills."\n}\n```'

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Accounting Admin',
#  'experience': '1 year of retail or consumer service experience',
#  'skills': ['Proficient knowledge of office practices, procedures, and equipment',
#   'Intermediate skills in Microsoft Office products including Word and Excel',
#   'Ability to learn and train on the latest products and technologies',
#   'Ability to communicate in English',
#   'Strong customer service skills and the ability to exercise a high degree of professionalism',
#   'Strong attention to detail and deadlines'],
#  'description': 'Administer advanced cashiering tasks, support scheduling, review associate tech functionality, and perform standard cashiering duties. The ideal candidate will have a strong ability to work in a fast-paced environment, be flexible, and have excellent communication skills.'}

# %%
type(json_res)
# Out:
# dict

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 76.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 77.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 15.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import uuid
import chromadb
df = pd.read_csv("my_portfolio.csv")
client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 73.4MiB/s]

# %%
job = json_res
job['skills']
# Out:
# ['Proficient knowledge of office practices, procedures, and equipment',
#  'Intermediate skills in Microsoft Office products including Word and Excel',
#  'Ability to learn and train on the latest products and technologies',
#  'Ability to communicate in English',
#  'Strong customer service skills and the ability to exercise a high degree of professionalism',
#  'Strong attention to detail and deadlines']

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/android-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/wordpress-portfolio'},
#   {'links': 'https://example.com/xamarin-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/ios-portfolio'},
#   {'links': 'https://example.com/full-stack-js-portfolio'}]]

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Ayushi Bhandari, a final year Computer Science Graduate student who is looking for an internship in the field of AI an ML majorly. Your projects are made mostly in the topics of deep learning implementing computer visoon and nlo. You have also worked on finetuning LLMs and are a certified AWS Cloud practitioner
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Ayushi Bhandari
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Application for Accounting Admin Role
#
# Dear Hiring Manager,
#
# I am excited to apply for the Accounting Admin position at your esteemed organization. Although my background is in Computer Science, I am eager to explore opportunities in administration and leverage my strong customer service skills and attention to detail.
#
# As a final year Computer Science Graduate student, I have developed strong analytical and problem-solving skills, which I believe will be valuable in this role. My experience in working on projects involving deep learning, computer vision, and NLP has taught me the importance of accuracy, deadlines, and effective communication.
#
# In addition to my technical skills, I have also worked on fine-tuning LLMs and hold a certification as an AWS Cloud Practitioner. I am confident that my ability to learn and adapt to new technologies and products will enable me to make a positive contribution to your team.
#
# ...
